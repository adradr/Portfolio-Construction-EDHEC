# %%
import quandl
import pandas as pd

# %%
btc = quandl.get("BITFINEX/BTCUSD")
eth = quandl.get("BITFINEX/ETHUSD")

# %%
l = ["Last"]

# %%
data = pd.DataFrame()

# %%
data = btc[l]

# %%
data = data.rename(columns={"Last": "BTC"})

# %%
data["ETH"] = eth[l]

# %%
data_change = data.pct_change()

# %%
data_change
# Out:
#                  BTC       ETH
# Date
# 2014-04-15       NaN       NaN
# 2014-04-16  0.065347       NaN
# 2014-04-17 -0.055762       NaN
# 2014-04-18 -0.049705       NaN
# 2014-04-19  0.051269       NaN
# ...              ...       ...
# 2019-11-06  0.000951  0.008314
# 2019-11-07 -0.015910 -0.024574
# 2019-11-08 -0.045139 -0.015028
# 2019-11-09  0.003466  0.005213
# 2019-11-10  0.026895  0.023767
#
# [1990 rows x 2 columns]

# %%
data_change.plot()

# %%
data.plot()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create some mock data
t = data.index
data1 = data["BTC"]
data2 = data["ETH"]

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time')
ax1.set_ylabel('BTC', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('ETH', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
