# %%
import pandas as pd
import numpy as np
import edhec_risk_kit as erk

# %%
ind = pd.read_csv("data/ind30_m_vw_rets.csv", header=0, index_col=0, parse_dates=True)/100

# %%
ind.index = pd.to_datetime(ind.index, format="%Y%m").to_period("M")

# %%
ind.head()
# Out:
#           Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals   Fin     Other
# ...

# %%
ind.shape
# Out:
# (1110, 30)

# %%
ind.columns
# Out:
# Index(['Food ', 'Beer ', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth ',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal ', 'Oil  ', 'Util ', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin  ', 'Other'],
#       dtype='object')

# %%
ind.columns = ind.columns.str.strip()

# %%
ind.columns
# Out:
# Index(['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other'],
#       dtype='object')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
erk.drawdown(ind["Food"])["Drawdown"].plot(figsize=(12, 6))

# %%
erk.var_gaussian(ind, modified=True).sort_values().plot.bar(title="Industry Gaussian VaR 1926-2018", figsize=(12,6))

# %%
erk.sharpe_ratio(ind,12).sort_values().plot.bar(title="Industry Sharpe ratio 1926-2018", figsize=(12,6))

# %%
erk.sharpe_ratio(ind["2000":],12).sort_values().plot.bar(title="Industry Sharpe ratio 2000-2018", figsize=(12,6))

# %%
erk.sharpe_ratio(ind["2008":],12).sort_values().plot.bar(
    title="Industry Sharpe ratio 2008-2018", 
    figsize=(12,6))

# %%
er = erk.annualized_return(ind["1995":"2000"], 12)

# %%
er.sort_values().plot.bar()

# %%
cov = ind["1995":"2000"].cov()

# %%
cov.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_340b996c_0182_11ea_9e29_0242ac110002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_340b996c_0182_11ea_9e29_0242ac110002row0_col1 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_340b996c_0182_11ea_9e29_0242ac110002row0_col2 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_340b996c_0182_11ea_9e29_0242ac110002row0_col3 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_340b996c_0182_11ea_9e29_0242ac110002row0_col4 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_340b996c_0182_11ea_9e29_0242ac110002row0_col5 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_340b996c_0182_11ea_9e29_0242ac110002row0_col6 {
#             background-color:  #799cf8;
#             color:  #000000;
# ...
