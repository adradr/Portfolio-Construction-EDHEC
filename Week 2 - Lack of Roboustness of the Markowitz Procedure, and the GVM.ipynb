# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
from scipy.optimize import minimize
import edhec_risk_kit as erk
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ind = erk.get_ind_returns()

# %%
er = erk.annualized_return(ind["1996":"2000"], 12)

# %%
cov = ind["1996":"2000"].cov()

# %%
l = ["Food", "Steel"]
erk.msr(0.1, er[l], cov.loc[l,l])
# Out:
# array([0.75040363, 0.24959637])

# %%
er[l]
# Out:
# Food     0.116799
# Steel    0.115809
# dtype: float64

# %%
erk.msr(0.1, np.array([.10,.12]), cov.loc[l,l])
# Out:
# array([0., 1.])

# %%
erk.plot_ef(20, er, cov, show_cml=True, riskfree=.1)

# %%
erk.plot_ef(20, er, cov, show_cml=True, riskfree=.1, show_ew=True)

# %%
erk.plot_ef(20, er, cov, show_cml=True, riskfree=.1, show_ew=True, show_gmv=True)
